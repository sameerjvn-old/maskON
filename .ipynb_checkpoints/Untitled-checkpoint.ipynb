# %%
from fastai.vision.widgets import *
import torchvision.transforms as T

# %%
URLHolder = widgets.Text(
    value='https://upload.wikimedia.org/wikipedia/commons/c/c3/COVID-19_%28Coronavirus%29_Girl_in_mask.jpg',
    placeholder='Type something',
    description='URL:',
    disabled=False
)

# %%
display(VBox([widgets.Label('Upload a face! (and hit enter)'), URLHolder]))

# %%
print(URLHolder.value)
# Out:
# https://upload.wikimedia.org/wikipedia/commons/c/c3/COVID-19_%28Coronavirus%29_Girl_in_mask.jpg

# %%
url = URLHolder.value

# %%
from PIL import Image
import requests
import matplotlib.pyplot as plt

response = requests.get(url, stream=True)
img = Image.open(response.raw)

plt.imshow(img)
plt.show()

# %%
print(img)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=2048x1365 at 0x7F6027A87160>

# %%
img_tensor = T.ToTensor()(img)
